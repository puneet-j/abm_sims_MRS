# %%
import networkx as nx
import numpy as np
import scipy.sparse as sp
import os
import time
from collections import defaultdict
# import tensorflow as tf
import pandas as pd
import pdb
from ast import literal_eval
import copy
import pickle
import sys
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'sim'))
from params import ENVIRONMENT_BOUNDARY_X, TIME_LIMIT, COMMIT_THRESHOLD
from math import sqrt
# from itertools import compress
from concurrent.futures import ThreadPoolExecutor, as_completed
import csv

# %%
def round_function(x, d):
    new = []
    for r in x:
        new.append(np.round(r,decimals=d))
    # pdb.set_trace()
    return tuple(new)

def new_state_from_old(old_):
    # pdb.set_trace()
    # qindices = 
    old = copy.deepcopy(old_)
    # pdb.set_trace()
    nA = int(len(old)/4)
    oldarr = np.reshape(old, (nA, 4)).tolist()
    sites_state = [1.0, 1.0, 0.0]*4
    unique_sites = defaultdict(int)
    # oldarr[:,0] = 0
    # oldarr_unique = np.unique(oldarr, axis=0)
    new = np.zeros((7,6))
    # counter_sites = [0, 0, 0, 0]*7
    # counter = 
    for i in oldarr:
        site = tuple(i[1:])
        unique_sites[site] += 1
    # print('1')
    
    sitelist = [i for i in unique_sites if i!= (1.0, 1.0, 0.0)]
    # quals = [i[2] for i in sitelist]
    # pdb.set_trace()
    sites = sorted(sitelist, key=lambda x: x[2] , reverse=True)
    site_to_id = dict()
    # print('2')
    for id, site in enumerate(sites):
        sites_state[id*3] = site[0]
        sites_state[id*3+1] = site[1]
        sites_state[id*3+2] = site[2]
        site_to_id[site] = id

    # print('3')
    for i in oldarr:
        id_state = int(np.round(6.0*i[0]))
        # print(id_state)
        if id_state >=5 :
            new[id_state,4] += 1.0/nA
        elif id_state == 4:
            new[id_state,5] += 1.0/nA
        else:
            site = tuple(i[1:])
            new[id_state, site_to_id[site]] += 1.0/nA
            if id_state == 0:
                new[id_state,5] += 1.0/nA
            else:
                new[id_state,4] += 1.0/nA


    return round_function(tuple(np.concatenate((np.reshape(new, (1,np.shape(new)[0]*np.shape(new)[1]))[0], sites_state), axis=0).tolist()), 3)

def get_unique_IDs(fl, dict_old, newdict, rd):
    states_unique = np.unique(fl.currentState)
    # states_new = np.zeros(72,)
    # for i in range(len(states_unique)):
    for i in states_unique:
        # pdb.set_trace()
        if i in dict_old:
            continue 
        else:
            dict_old[i] = len(dict_old)
            newstate = new_state_from_old(i)
            rd[newstate] = i
            newdict[newstate] = len(newdict)
    return dict_old, newdict, rd #, nodeSize

def get_edges_success_time(fl, IDLookupnew, get_edges_with, success_dict, time_dict, success, time_conv):
    # fl['newState'] = fl.apply(lambda x: rd[x.currentState], axis=1)
    fl['stateIDs'] = fl.apply(lambda x: IDLookupnew[x.currentState], axis=1)
    # pdb.set_trace()
    for id, (csid, time_val) in enumerate(zip(fl.stateIDs.values, fl.time.values)):
        if csid in time_dict:
            time_dict[csid].append(time_conv - time_val)
        else:
            time_dict[csid] = [time_conv - time_val]

        if csid in success_dict:
            success_dict[csid].append(success)
        else:
            success_dict[csid] = [success]
        

        if id+1 == len(fl.stateIDs.values):
            break
        if csid in get_edges_with:
            get_edges_with[csid].append(fl.stateIDs.values[id+1])
        else:
            get_edges_with[csid] = [fl.stateIDs.values[id+1]]
        # if csid == 88:
        #     pdb.set_trace()


    return get_edges_with, success_dict, time_dict

# %%
def process_file(folder_main, file_list, successes, times, quals):
    graph = nx.Graph()
    qrounded = [np.round(q, decimals=3) for q in quals]
    sortedquals = np.sort(list(quals))
    success_vals = []
    for s in successes:
        # print(s, sortedquals[-1])
        success_vals.append(s/sortedquals[-1])
    meanSuccess = np.mean(success_vals)
    meanTime = np.mean(times)
    has_edges_with = dict()
    IDLookup = dict()
    IDLookupnew = dict()
    reversedict = dict()
    success_dict = dict()
    time_dict = dict()
    for id_file, f in enumerate(file_list):
        fl = pd.read_csv(folder_main + f)
        fl.agent_states = fl.agent_states.apply(literal_eval)
        fl.agent_sites = fl.agent_sites.apply(literal_eval)
        fl.agent_positions = fl.agent_positions.apply(literal_eval)
        fl['currentState'] = fl.node.apply(literal_eval)
        success_now = success_vals[id_file]
        time_conv = times[id_file]
        IDLookup, IDLookupnew, reversedict = get_unique_IDs(fl, IDLookup, IDLookupnew, reversedict)
        has_edges_with, success_dict, time_dict = get_edges_success_time(fl, IDLookup, has_edges_with, success_dict, time_dict, success_now, time_conv)
        
    for nodePos, nodeID in IDLookupnew.items():
        graph.add_node(nodeID, x=nodePos, xold = reversedict[nodePos], 
                       success=success_dict[nodeID], time=time_dict[nodeID])

    for node,value in has_edges_with.items():
        for edge_to in value:
            if graph.has_edge(node, edge_to):
                graph[node][edge_to]['weight'] += 1.0
            else:
                graph.add_edge(node, edge_to, weight=1.0)

    nA = len(fl.agent_positions.iloc[0])
    colors = 'b'
    nx.set_node_attributes(graph, nA, 'agents')
    # nx.set_node_attributes(graph, colors, 'colors')
    nx.set_node_attributes(graph, qrounded, 'quals')
    # nx.set_node_attributes(graph, entry[1].iloc[1], 'poses')
    # nx.set_node_attributes(graph, meanSuccess, 'success')
    # nx.set_node_attributes(graph, meanTime, 'times_conved')
    # nx.set_node_attributes(graph, 0, 'global_info')
    # fl.node = lite
    # start_node_id = IDLookup[fl.iloc[0]['currentState']]

    # for node in graph.nodes(data=True):
    #     if node[0] == start_node_id:
    #         graph.nodes[node[0]]['times_conved'] = meanTime
    #     else:
    #         graph.nodes[node[0]]['times_conved'] = -1

    return graph, new_state_from_old(fl.iloc[0]['currentState'])

# %%
folder_main = './data/lots_of_node_samples/train_all_labels/'
metadata_file = folder_main + 'metadata.csv'
metadata = pd.read_csv(metadata_file) 
metadata.site_qualities=metadata.site_qualities.apply(literal_eval)
metadata.site_positions=metadata.site_positions.apply(literal_eval)
metadata.site_positions=metadata.site_positions.apply(lambda x: tuple([tuple(a) for a in x]))
metadata.site_qualities=metadata.site_qualities.apply(lambda x: tuple(x))
# metadata.node=metadata.node.apply(literal_eval)
# metadata.sims_train = metadata.sims_train.apply(lambda x: literal_eval(x))
# metadata.site_converged = metadata.site_converged.apply(lambda x: literal_eval(x))
# metadata.time_converged = metadata.time_converged.apply(lambda x: literal_eval(x))
df = metadata.groupby(by=['site_qualities', 'site_positions', 'num_agents', 'node'], as_index=False).agg(lambda x: x.tolist())
# df = metadata.groupby(by=['start_state'], as_index=False).agg(lambda x: x.tolist())

# %%
# dict_node_state = dict()
# # list_state = []
# for some_id, entry in enumerate(df.iterrows()):
#     node = entry[1].iloc[3]
#     state = entry[1].iloc[4]
#     if node in dict_node_state:
#         if dict_node_state[node] == state:
#             continue
#         else:
#             print('node: ', node)
#             print('state 1: ', state)
#             print('state 2: ', dict_node_state[node])
#     else:
#         dict_node_state[node] = state

# %%
import time
dictnew_time = dict()
dictnew_succ = dict()
dict_files = dict()
folder_graph = folder_main + 'graphs/'
ml = 0
for some_id, entry in enumerate(df.iterrows()):
    times = entry[1].iloc[7]
    ml = len(times) if len(times) > ml else ml

for some_id, entry in enumerate(df.iterrows()):
    # break
    graph_name = str(int(time.time()*1000000))#entry[1].iloc[3]
    graphs_train = entry[1].iloc[4]
    successes = entry[1].iloc[6]
    times = entry[1].iloc[7]
    quals = entry[1].iloc[0]
    # print(graphs_train, successes, times, quals)
    graph, node = process_file(folder_main, graphs_train, successes, times, quals)
    print('number of nodes: ', graph.number_of_nodes())
    # print('number of edges: ', graph.number_of_edges())
    # print('average degree: ', sum(dict(graph.degree()).values()) / graph.number_of_nodes())
    # folder_graph = folder_main + 'graphs/'
    fil = open(folder_graph+str(graph_name)+'.pickle', 'wb')
    pickle.dump(graph, fil)
    fil.close()
    # dictnew_time[str(node)] = times + [np.nan] * (ml - len(times))
    # dictnew_succ[str(node)] = successes + [np.nan] * (ml - len(times))
    # for g in graphs_train:
    #     dict_files[g] = str(node)

# print(dictnew_time)
# dftime = pd.DataFrame.from_dict(dictnew_time)#, orient='index', columns=['file', 'times'])
# dfsucc = pd.DataFrame.from_dict(dictnew_succ)#, orient='index', columns=['file', 'succ'])
# dffiles = pd.DataFrame.from_dict(dict_files, orient='index', columns=['ref'])

# # print(dftime[graph_name+'.pickle'].tolist())
# dftime.to_csv(folder_graph+'times.csv')
# dfsucc.to_csv(folder_graph+'succ.csv')
# dffiles.to_csv(folder_graph+'files.csv')
    # break 
# print(entry)
# Out:
# number of nodes:  3619
# number of nodes:  3996
# number of nodes:  1990
# number of nodes:  3202
# number of nodes:  1949
# number of nodes:  4182
# number of nodes:  1360
# number of nodes:  3201
# number of nodes:  4014
# number of nodes:  6020
# number of nodes:  6510
# number of nodes:  6550
# number of nodes:  9569
# number of nodes:  5488
# number of nodes:  1941
# number of nodes:  4837
# number of nodes:  8450
# number of nodes:  6871
# number of nodes:  9162
# number of nodes:  6902
# number of nodes:  3588
# number of nodes:  1996
# number of nodes:  12434
# number of nodes:  10160
# number of nodes:  11918
# number of nodes:  4855
# number of nodes:  5501
# number of nodes:  10016
# number of nodes:  17938
# number of nodes:  4534
# number of nodes:  7175
# number of nodes:  11719
# number of nodes:  3409
# number of nodes:  12146
# number of nodes:  13352
# number of nodes:  2581
# number of nodes:  2342
# number of nodes:  2350
# number of nodes:  4751
# number of nodes:  2538
# number of nodes:  1001
# number of nodes:  2796
# number of nodes:  1680
# number of nodes:  1900
# number of nodes:  1802
# number of nodes:  1754
# number of nodes:  391
# number of nodes:  601
# number of nodes:  391
# number of nodes:  2566
# number of nodes:  1943
# number of nodes:  2254
# number of nodes:  2104
# number of nodes:  1974
# number of nodes:  878
# number of nodes:  1080
# number of nodes:  2344
# number of nodes:  4390
# number of nodes:  1079
# number of nodes:  2322
# number of nodes:  2223
# number of nodes:  2501
# number of nodes:  1006
# number of nodes:  3265
# number of nodes:  1026
# number of nodes:  3661
# number of nodes:  2682
# number of nodes:  2513
# number of nodes:  993
# number of nodes:  2080
# number of nodes:  2813
# number of nodes:  2563
# number of nodes:  2056
# number of nodes:  2239
# number of nodes:  925
# number of nodes:  3591
# number of nodes:  4403
# number of nodes:  2131
# number of nodes:  5332
# number of nodes:  852
# number of nodes:  1483
# number of nodes:  1780
# number of nodes:  2626
# number of nodes:  1839
# number of nodes:  1480
# number of nodes:  1069
# number of nodes:  1973
# number of nodes:  3131
# number of nodes:  1136
# number of nodes:  4670
# number of nodes:  871
# number of nodes:  2678
# number of nodes:  2919
# number of nodes:  2793
# number of nodes:  2467
# number of nodes:  2168
# number of nodes:  3144
# number of nodes:  2780
# number of nodes:  2960
# number of nodes:  1190
# number of nodes:  647
# number of nodes:  2378
# number of nodes:  591
# number of nodes:  2920
# number of nodes:  2186
# number of nodes:  1247
# number of nodes:  1535
# number of nodes:  1579
# number of nodes:  1565
# number of nodes:  1669
# number of nodes:  1351
# number of nodes:  183
# number of nodes:  316
# number of nodes:  2858
# number of nodes:  2667
# number of nodes:  1977
# number of nodes:  2567
# number of nodes:  1882
# number of nodes:  2839
# number of nodes:  2180
# number of nodes:  1059
# number of nodes:  2284
# number of nodes:  2482
# number of nodes:  2393
# number of nodes:  1941
# number of nodes:  2325
# number of nodes:  1119
# number of nodes:  1036
# number of nodes:  3994
# number of nodes:  1532
# number of nodes:  2076
# number of nodes:  1032
# number of nodes:  2040
# number of nodes:  1701
# number of nodes:  1089
# number of nodes:  5295
# number of nodes:  1205
# number of nodes:  1257
# number of nodes:  3235
# number of nodes:  1985
# number of nodes:  1744
# number of nodes:  2117
# number of nodes:  2234
# number of nodes:  1165
# number of nodes:  1095
# number of nodes:  2848
# number of nodes:  2977
# number of nodes:  1777
# number of nodes:  430
# number of nodes:  1567
# number of nodes:  1424
# number of nodes:  1766
# number of nodes:  791
# number of nodes:  2839
# number of nodes:  3002
# number of nodes:  3059
# number of nodes:  2876
# number of nodes:  2726
# number of nodes:  1885
# number of nodes:  2996
# number of nodes:  1323
# number of nodes:  510
# number of nodes:  1440
# number of nodes:  1365
# number of nodes:  1462
# number of nodes:  1836
# number of nodes:  1468
# number of nodes:  1419
# number of nodes:  382
# number of nodes:  1364
# number of nodes:  1227
# number of nodes:  1490
# number of nodes:  1342
# number of nodes:  243
# number of nodes:  279
# number of nodes:  1514
# number of nodes:  324
# number of nodes:  238
# number of nodes:  174
# number of nodes:  645
# number of nodes:  490
# number of nodes:  1336
# number of nodes:  1489
# number of nodes:  1220
# number of nodes:  1966
# number of nodes:  491
# number of nodes:  693
# number of nodes:  799
# number of nodes:  229
# number of nodes:  2424
# number of nodes:  735
# number of nodes:  1887
# number of nodes:  759
# number of nodes:  1421
# number of nodes:  1604
# number of nodes:  1281
# number of nodes:  291
# number of nodes:  252
# number of nodes:  325
# number of nodes:  207
# number of nodes:  192
# number of nodes:  263
# number of nodes:  122
# number of nodes:  1390
# number of nodes:  1303
# number of nodes:  251
# number of nodes:  1265
# number of nodes:  1600
# number of nodes:  1010
# number of nodes:  286
# number of nodes:  235
# number of nodes:  1838
# number of nodes:  286
# number of nodes:  317
# number of nodes:  945
# number of nodes:  377
# number of nodes:  341
# number of nodes:  231
# number of nodes:  428
# number of nodes:  387
# number of nodes:  259
# number of nodes:  1901
# number of nodes:  2857
# number of nodes:  3315
# number of nodes:  3670
# number of nodes:  2684
# number of nodes:  2633
# number of nodes:  2489
# number of nodes:  2380
# number of nodes:  2259
# number of nodes:  1051
# number of nodes:  1135
# number of nodes:  2760
# number of nodes:  1064
# number of nodes:  1027
# number of nodes:  793
# number of nodes:  2285
# number of nodes:  805
# number of nodes:  2178
# number of nodes:  1872
# number of nodes:  822
# number of nodes:  1847
# number of nodes:  2935
# number of nodes:  906
# number of nodes:  961
# number of nodes:  1672
# number of nodes:  2610
# number of nodes:  2388
# number of nodes:  872
# number of nodes:  2107
# number of nodes:  691
# number of nodes:  1560
# number of nodes:  2169
# number of nodes:  747
# number of nodes:  915
# number of nodes:  1174
# number of nodes:  1014
# number of nodes:  618
# number of nodes:  2747
# number of nodes:  1572
# number of nodes:  1694
# number of nodes:  1801
# number of nodes:  668
# number of nodes:  749
# number of nodes:  682
# number of nodes:  698
# number of nodes:  2969
# number of nodes:  756
# number of nodes:  741
# number of nodes:  1953
# number of nodes:  1765
# number of nodes:  639
# number of nodes:  572
# number of nodes:  751
# number of nodes:  570
# number of nodes:  1293
# number of nodes:  2363
# number of nodes:  1088
# number of nodes:  546
# number of nodes:  567
# number of nodes:  671
# number of nodes:  719
# number of nodes:  526
# number of nodes:  1857
# number of nodes:  1614
# number of nodes:  1364
# number of nodes:  801
# number of nodes:  525
# number of nodes:  987
# number of nodes:  859
# number of nodes:  1445
# number of nodes:  1402
# number of nodes:  1390
# number of nodes:  1226
# number of nodes:  589
# number of nodes:  405
# number of nodes:  463
# number of nodes:  506
# number of nodes:  489
# number of nodes:  1171
# number of nodes:  946
# number of nodes:  273
# number of nodes:  2241
# number of nodes:  2158
# number of nodes:  674
# number of nodes:  1464
# number of nodes:  2327
# number of nodes:  1365
# number of nodes:  701
# number of nodes:  788
# number of nodes:  504
# number of nodes:  859
# number of nodes:  2902
# number of nodes:  621
# number of nodes:  3484
# number of nodes:  1170
# number of nodes:  564
# number of nodes:  2762
# number of nodes:  425
# number of nodes:  491
# number of nodes:  390
# number of nodes:  891
# number of nodes:  1162
# number of nodes:  1604
# number of nodes:  1189
# number of nodes:  797
# number of nodes:  865
# number of nodes:  910
# number of nodes:  1335
# number of nodes:  740
# number of nodes:  982
# number of nodes:  2000
# number of nodes:  385
# number of nodes:  392
# number of nodes:  721
# number of nodes:  870
# number of nodes:  240
# number of nodes:  1170
# number of nodes:  989
# number of nodes:  408
# number of nodes:  2442
# number of nodes:  220
# number of nodes:  553
# number of nodes:  559
# number of nodes:  527
# number of nodes:  1955
# number of nodes:  1709
# number of nodes:  1591
# number of nodes:  915
# number of nodes:  792
# number of nodes:  2098
# number of nodes:  287
# number of nodes:  498
# number of nodes:  1620
# number of nodes:  339
# number of nodes:  1454
# number of nodes:  2650
# number of nodes:  3820
# number of nodes:  1199
# number of nodes:  423
# number of nodes:  826
# number of nodes:  1566
# number of nodes:  2342
# number of nodes:  1385
# number of nodes:  946
# number of nodes:  992
# number of nodes:  2171
# number of nodes:  1089
# number of nodes:  578
# number of nodes:  825
# number of nodes:  1015
# number of nodes:  642
# number of nodes:  817
# number of nodes:  1215
# number of nodes:  545
# number of nodes:  355
# number of nodes:  193
# number of nodes:  224
# number of nodes:  579
# number of nodes:  968
# number of nodes:  681
# number of nodes:  1204
# number of nodes:  743
# number of nodes:  341
# number of nodes:  1030
# number of nodes:  1358
# number of nodes:  642
# number of nodes:  1382
# number of nodes:  288
# number of nodes:  1694
# number of nodes:  425
# number of nodes:  413
# number of nodes:  293
# number of nodes:  655
# number of nodes:  565
# number of nodes:  334
# number of nodes:  867
# number of nodes:  1119
# number of nodes:  1775
# number of nodes:  659
# number of nodes:  426
# number of nodes:  789
# number of nodes:  115
# number of nodes:  842
# number of nodes:  212
# number of nodes:  630
# number of nodes:  679
# number of nodes:  88
# number of nodes:  338
# number of nodes:  693
# number of nodes:  172
# number of nodes:  674
# number of nodes:  129
# number of nodes:  793
# number of nodes:  1046
# number of nodes:  522
# number of nodes:  1052
# number of nodes:  317
# number of nodes:  497
# number of nodes:  791
# number of nodes:  439
# number of nodes:  667
# number of nodes:  333
# number of nodes:  785
# number of nodes:  268
# number of nodes:  90
# number of nodes:  797
# number of nodes:  1157
# number of nodes:  1151
# number of nodes:  223
# number of nodes:  378
# number of nodes:  768
# number of nodes:  199
# number of nodes:  847
# number of nodes:  897
# number of nodes:  1993
# number of nodes:  2335
# number of nodes:  3317
# number of nodes:  2426
# number of nodes:  1156
# number of nodes:  678
# number of nodes:  715
# number of nodes:  1138
# number of nodes:  3303
# number of nodes:  3558
# number of nodes:  1914
# number of nodes:  1762
# number of nodes:  1846
# number of nodes:  2087
# number of nodes:  1137
# number of nodes:  634
# number of nodes:  1940
# number of nodes:  2336
# number of nodes:  1773
# number of nodes:  611
# number of nodes:  571
# number of nodes:  1641
# number of nodes:  1653
# number of nodes:  1699
# number of nodes:  1886
# number of nodes:  981
# number of nodes:  1403
# number of nodes:  1081
# number of nodes:  1717
# number of nodes:  406
# number of nodes:  821
# number of nodes:  1383
# number of nodes:  1885
# number of nodes:  317
# number of nodes:  1767
# number of nodes:  1041
# number of nodes:  179
# number of nodes:  964
# number of nodes:  1060
# number of nodes:  637
# number of nodes:  2372
# number of nodes:  286
# number of nodes:  139
# number of nodes:  713
# number of nodes:  71
# number of nodes:  2380
# number of nodes:  1457
# number of nodes:  489
# number of nodes:  1293
# number of nodes:  1068
# number of nodes:  343
# number of nodes:  1958
# number of nodes:  928
# number of nodes:  1056
# number of nodes:  1194
# number of nodes:  1138
# number of nodes:  1168
# number of nodes:  1049
# number of nodes:  964
# number of nodes:  691
# number of nodes:  917
# number of nodes:  171
# number of nodes:  360
# number of nodes:  917
# number of nodes:  102
# number of nodes:  764
# number of nodes:  629
# number of nodes:  988
# number of nodes:  766
# number of nodes:  1733
# number of nodes:  1109
# number of nodes:  1546
# number of nodes:  1071
# number of nodes:  1712
# number of nodes:  175
# number of nodes:  170
# number of nodes:  375
# number of nodes:  347
# number of nodes:  1077
# number of nodes:  1154
# number of nodes:  154
# number of nodes:  148
# number of nodes:  481
# number of nodes:  1069
# number of nodes:  62
# number of nodes:  146
# number of nodes:  1094
# number of nodes:  908
# number of nodes:  115
# number of nodes:  711
# number of nodes:  599
# number of nodes:  652
# number of nodes:  96
# number of nodes:  957
# number of nodes:  191
# number of nodes:  673
# number of nodes:  140
# number of nodes:  459
# number of nodes:  508
# number of nodes:  617
# number of nodes:  834
# number of nodes:  1008
# number of nodes:  2705
# number of nodes:  570
# number of nodes:  2790
# number of nodes:  2271
# number of nodes:  864
# number of nodes:  2358
# number of nodes:  2140
# number of nodes:  2327
# number of nodes:  2507
# number of nodes:  2410
# number of nodes:  2325
# number of nodes:  1689
# number of nodes:  1366
# number of nodes:  1060
# number of nodes:  1191
# number of nodes:  1453
# number of nodes:  1220
# number of nodes:  2258
# number of nodes:  476
# number of nodes:  482
# number of nodes:  564
# number of nodes:  772
# number of nodes:  1163
# number of nodes:  1337
# number of nodes:  1296
# number of nodes:  1260
# number of nodes:  250
# number of nodes:  1329
# number of nodes:  221
# number of nodes:  1330
# number of nodes:  1437
# number of nodes:  656
# number of nodes:  1218
# number of nodes:  558
# number of nodes:  2254
# number of nodes:  194
# number of nodes:  130
# number of nodes:  463
# number of nodes:  408
# number of nodes:  134
# number of nodes:  512
# number of nodes:  60
# number of nodes:  1742
# number of nodes:  1131
# number of nodes:  1436
# number of nodes:  1008
# number of nodes:  272
# number of nodes:  1071
# number of nodes:  186
# number of nodes:  961
# number of nodes:  186
# number of nodes:  766
# number of nodes:  1387
# number of nodes:  581
# number of nodes:  806
# number of nodes:  1260
# number of nodes:  532
# number of nodes:  66
# number of nodes:  1419
# number of nodes:  1563
# number of nodes:  947
# number of nodes:  197
# number of nodes:  1219
# number of nodes:  1496
# number of nodes:  907
# number of nodes:  189
# number of nodes:  417
# number of nodes:  233
# number of nodes:  1244
# number of nodes:  1024
# number of nodes:  670
# number of nodes:  119
# number of nodes:  959
# number of nodes:  1487
# number of nodes:  1313
# number of nodes:  77
# number of nodes:  97
# number of nodes:  467
# number of nodes:  777
# number of nodes:  262
# number of nodes:  1239
# number of nodes:  458
# number of nodes:  1939
# number of nodes:  2373
# number of nodes:  2348
# number of nodes:  2385
# number of nodes:  2659
# number of nodes:  2293
# number of nodes:  2626
# number of nodes:  2132
# number of nodes:  717
# number of nodes:  2063
# number of nodes:  2409
# number of nodes:  2675
# number of nodes:  2337
# number of nodes:  1480
# number of nodes:  319
# number of nodes:  1348
# number of nodes:  767
# number of nodes:  1286
# number of nodes:  388
# number of nodes:  1863
# number of nodes:  932
# number of nodes:  1010
# number of nodes:  887
# number of nodes:  233
# number of nodes:  221
# number of nodes:  208
# number of nodes:  42
# number of nodes:  174
# number of nodes:  129
# number of nodes:  38
# number of nodes:  408
# number of nodes:  462
# number of nodes:  226
# number of nodes:  499
# number of nodes:  428
# number of nodes:  231
# number of nodes:  219
# number of nodes:  1422
# number of nodes:  868
# number of nodes:  195
# number of nodes:  230
# number of nodes:  967
# number of nodes:  770
# number of nodes:  205
# number of nodes:  143
# number of nodes:  120
# number of nodes:  182
# number of nodes:  1183
# number of nodes:  131
# number of nodes:  796
# number of nodes:  1184
# number of nodes:  1259
# number of nodes:  369
# number of nodes:  60
# number of nodes:  449
# number of nodes:  53
# number of nodes:  200
# number of nodes:  239
# number of nodes:  702
# number of nodes:  95
# number of nodes:  338
# number of nodes:  149
# number of nodes:  687
# number of nodes:  852
# number of nodes:  576
# number of nodes:  1870
# number of nodes:  673
# number of nodes:  480
# number of nodes:  2072
# number of nodes:  1022
# number of nodes:  386
# number of nodes:  1595
# number of nodes:  155
# number of nodes:  104
# number of nodes:  432
# number of nodes:  161
# number of nodes:  93
# number of nodes:  119
# number of nodes:  220
# number of nodes:  140
# number of nodes:  105
# number of nodes:  69
# number of nodes:  642
# number of nodes:  93
# number of nodes:  47
# number of nodes:  11
# number of nodes:  135
# number of nodes:  278
# number of nodes:  291
# number of nodes:  176
# number of nodes:  536
# number of nodes:  101
# number of nodes:  44
# number of nodes:  498
# number of nodes:  504
# number of nodes:  529
# number of nodes:  799
# number of nodes:  38
# number of nodes:  127
# number of nodes:  441
# number of nodes:  25
# number of nodes:  24
# number of nodes:  31
# number of nodes:  144
# number of nodes:  116
# number of nodes:  5
# number of nodes:  49
# number of nodes:  41
# number of nodes:  5
# number of nodes:  4
# number of nodes:  20
# number of nodes:  5
# number of nodes:  14
# number of nodes:  4

# %%
# # CHECK GRAPHS
# files = os.listdir(folder_graph)
# files = [file for file in files if file.endswith('.pickle') and file.startswith('1')]
# fil = open(folder_graph + files[0], 'rb')
# G = pickle.load(fil)
# fil.close()
# for node in G.nodes(data=True):
#     print(node)
# # G.nodes[1]
