# %%
import os 
import sys
import pandas as pd 
import numpy as np

folder = './data/quorum_sims_70_30_split/'
files = os.listdir(folder)
files = [file for file in files if file.endswith('.csv') and file.startswith('1')]
meta = pd.read_csv(folder+'metadata.csv')

# %%
submeta = pd.DataFrame([],columns=meta.columns)
submeta
# Out:
# Empty DataFrame
# Columns: [file_name, site_qualities, site_positions, hub_position, num_agents, site_converged, time_converged, start_state, maxTime]
# Index: []

# %%
import pdb
# files.remove('metadata.csv')
for file in files:
    
    row = meta.loc[meta.file_name==file].values
    # print(row, len(row[0]))
    try:
        submeta.loc[-1] = row[0]  # adding a row
    except:
        pdb.set_trace()
    # break
    submeta.index = submeta.index + 1  # shifting index
    submeta = submeta.sort_index()  # sorting by index
    # break
submeta
# Out:
#                 file_name                site_qualities  \
# 0    1720158810492470.csv  [0.542, 0.476, 0.438, 0.584]
# 1    1720158810509888.csv  [0.542, 0.476, 0.438, 0.584]
# 2    1720158810518013.csv  [0.542, 0.476, 0.438, 0.584]
# 3    1720158810486161.csv  [0.542, 0.476, 0.438, 0.584]
# 4    1720158810521484.csv  [0.542, 0.476, 0.438, 0.584]
# ..                    ...                           ...
# 534  1720158810501229.csv  [0.542, 0.476, 0.438, 0.584]
# 535  1720158810499500.csv  [0.542, 0.476, 0.438, 0.584]
# 536  1720158810513611.csv  [0.542, 0.476, 0.438, 0.584]
# 537  1720158810518744.csv  [0.542, 0.476, 0.438, 0.584]
# 538  1720158810490518.csv  [0.542, 0.476, 0.438, 0.584]
#
#                                         site_positions hub_position  \
# 0    [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 1    [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 2    [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 3    [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 4    [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# ..                                                 ...          ...
# 534  [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 535  [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 536  [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 537  [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
# 538  [[150.0, 0.0], [0.0, 150.0], [-150.0, 0.0], [-...   [0.0, 0.0]
#
#     num_agents site_converged time_converged  \
# 0           10          0.584           2322
# 1           10          0.584           4015
# 2           10          0.584           1492
# 3           10          0.542           2690
# 4           10          0.476            443
# ..         ...            ...            ...
# 534         10          0.584           7949
# 535         10          0.584           7959
# 536         10          0.542           2051
# 537         10          0.584          14261
# 538         10          0.584           3348
#
#                                            start_state maxTime
# 0    (('OBSERVE', None), ('ASSESS', 0), ('ASSESS', ...   35000
# 1    (('EXPLORE', None), ('RECRUIT', 3), ('RECRUIT'...   35000
# 2    (('RECRUIT', 3), ('OBSERVE', None), ('ASSESS',...   35000
# 3                                                   ()   35000
# 4    (('OBSERVE', None), ('OBSERVE', None), ('RECRU...   35000
# ..                                                 ...     ...
# 534  (('OBSERVE', None), ('OBSERVE', None), ('OBSER...   35000
# 535  (('RECRUIT', 1), ('OBSERVE', None), ('OBSERVE'...   35000
# 536  (('EXPLORE', None), ('RECRUIT', 1), ('RECRUIT'...   35000
# 537  (('EXPLORE', None), ('EXPLORE', None), ('RECRU...   35000
# 538  (('OBSERVE', None), ('OBSERVE', None), ('OBSER...   35000
#
# [539 rows x 9 columns]

# %%
from ast import literal_eval
submeta.site_qualities=submeta.site_qualities.apply(literal_eval)
submeta.site_positions=submeta.site_positions.apply(literal_eval)
submeta.site_qualities=submeta.site_qualities.apply(lambda x: tuple(x))
submeta.site_positions=submeta.site_positions.apply(lambda x: tuple([tuple(a) for a in x]))

df = submeta.groupby(by=['site_qualities', 'site_positions', 'num_agents'], as_index=False).agg(lambda x: x.tolist())

# %%
df['numentries'] = df.maxTime.apply(lambda x: len(x))
df.numentries
# Out:
# 0    539
# Name: numentries, dtype: int64

# %%
files_to_save_one_graph = df.iloc[0]['file_name']

# import os 
# import shutil
# import numpy as np
# fold = '../final_experiments/allGraphs_train/'
# fold_new = '../final_experiments/allGraphs_test/'
# files = os.listdir(fold)
# for file in files[:-1]:
#     if np.random.random() > 0.7:
#         print(file)
#         shutil.move(fold+file, fold_new+file)

# %%
len(files_to_save_one_graph)
# Out:
# 539

# %%
import shutil
# for file in files_to_save_one_graph:
# # try:
#     shutil.copy(folder+file, './data/quorumsims_fixed_otheragents/'+file)
#     # except:
#         # continue

# %%
print(files_to_save_one_graph)
for file in files_to_save_one_graph:
    if np.random.random() < 0.6:
        # print(file)
        shutil.move(folder+file, folder + 'train/'+file)
# Out:
# ['1720158810492470.csv', '1720158810509888.csv', '1720158810518013.csv', '1720158810486161.csv', '1720158810521484.csv', '1720158810510856.csv', '1720158810520995.csv', '1720158810507279.csv', '1720158810514577.csv', '1720158810512660.csv', '1720158810508176.csv', '1720158810500258.csv', '1720158810522012.csv', '1720158810518629.csv', '1720158810519279.csv', '1720158810517526.csv', '1720158810520349.csv', '1720158810523866.csv', '1720158810498982.csv', '1720158810516177.csv', '1720158810515318.csv', '1720158810508822.csv', '1720158810519708.csv', '1720158810511585.csv', '1720158810523537.csv', '1720158810491346.csv', '1720158810510300.csv', '1720158810521861.csv', '1720158810519326.csv', '1720158810516029.csv', '1720158810502048.csv', '1720158810511961.csv', '1720158810522401.csv', '1720158810500688.csv', '1720158810516559.csv', '1720158810517848.csv', '1720158810517690.csv', '1720158810501780.csv', '1720158810503008.csv', '1720158810516377.csv', '1720158810502458.csv', '1720158810517733.csv', '1720158810521256.csv', '1720158810512307.csv', '1720158810492261.csv', '1720158810513970.csv', '1720158810513781.csv', '1720158810514978.csv', '1720158810514005.csv', '1720158810501408.csv', '1720158810491231.csv', '1720158810522951.csv', '1720158810511431.csv', '1720158810504014.csv', '1720158810516410.csv', '1720158810501742.csv', '1720158810505530.csv', '1720158810500460.csv', '1720158810513839.csv', '1720158810502713.csv', '1720158810517326.csv', '1720158810507848.csv', '1720158810492674.csv', '1720158810490659.csv', '1720158810490881.csv', '1720158810490117.csv', '1720158810517246.csv', '1720158810520398.csv', '1720158810521086.csv', '1720158810517291.csv', '1720158810514798.csv', '1720158810523647.csv', '1720158810505119.csv', '1720158810510272.csv', '1720158810518148.csv', '1720158810515691.csv', '1720158810500505.csv', '1720158810511352.csv', '1720158810499091.csv', '1720158810520004.csv', '1720158810507336.csv', '1720158810517125.csv', '1720158810520951.csv', '1720158810519493.csv', '1720158810511781.csv', '1720158810518996.csv', '1720158810485679.csv', '1720158810512539.csv', '1720158810492313.csv', '1720158810523902.csv', '1720158810489914.csv', '1720158810503620.csv', '1720158810515724.csv', '1720158810490060.csv', '1720158810512705.csv', '1720158810505292.csv', '1720158810522163.csv', '1720158810492878.csv', '1720158810507532.csv', '1720158810519917.csv', '1720158810515863.csv', '1720158810503556.csv', '1720158810511191.csv', '1720158810522201.csv', '1720158810489849.csv', '1720158810518836.csv', '1720158810490471.csv', '1720158810504238.csv', '1720158810503972.csv', '1720158810501181.csv', '1720158810499870.csv', '1720158810521523.csv', '1720158810519043.csv', '1720158810510701.csv', '1720158810518361.csv', '1720158810508748.csv', '1720158810517654.csv', '1720158810491196.csv', '1720158810499535.csv', '1720158810506573.csv', '1720158810514177.csv', '1720158810508511.csv', '1720158810505035.csv', '1720158810522475.csv', '1720158810512005.csv', '1720158810492177.csv', '1720158810514306.csv', '1720158810521418.csv', '1720158810491278.csv', '1720158810523384.csv', '1720158810511487.csv', '1720158810510570.csv', '1720158810500763.csv', '1720158810491907.csv', '1720158810514930.csv', '1720158810516699.csv', '1720158810507757.csv', '1720158810486249.csv', '1720158810499427.csv', '1720158810519555.csv', '1720158810503928.csv', '1720158810505418.csv', '1720158810510767.csv', '1720158810522851.csv', '1720158810515025.csv', '1720158810507810.csv', '1720158810510405.csv', '1720158810499235.csv', '1720158810521180.csv', '1720158810515580.csv', '1720158810501287.csv', '1720158810519635.csv', '1720158810516260.csv', '1720158810504664.csv', '1720158810511533.csv', '1720158810520739.csv', '1720158810513495.csv', '1720158810510836.csv', '1720158810490165.csv', '1720158810491051.csv', '1720158810503527.csv', '1720158810498934.csv', '1720158810515393.csv', '1720158810505625.csv', '1720158810516103.csv', '1720158810507224.csv', '17201588105156 ...

# %%
folder_t = folder + 'train/'
files = os.listdir(folder_t)
files = [file for file in files if file.endswith('.csv')]
# fileNames = []
# siteConv = []
# timeConv = []
# siteQuals = []
# sitePoses = []
# numAg = []
submeta = pd.DataFrame([],columns=meta.columns)

for file in files:
    row = meta.loc[meta.file_name==file].values
    try:
        submeta.loc[-1] = row[0]  # adding a row
    except:
        pdb.set_trace()
    # break
    submeta.index = submeta.index + 1  # shifting index
    submeta = submeta.sort_index()  # sorting by index
    # fileNames.append(row.file_name)
    # siteConv.append(row.site_converged)
    # timeConv.append(row.time_converged)
    # siteQuals.append(row.site_qualities)
    # sitePoses.append(row.site_positions)
    # numAg.append(row.num_agents)
    # break
submeta.to_csv(folder_t+'metadata.csv')
# row
# [(fileName, site_conv, time_conv, entry, folder, folder_graph1, folder_graph2)

# %%
# folder = 'data/quorum_sims_all/'
print(folder)
folderto = folder + 'test/'
files = os.listdir(folder)
files = [file for file in files if file.endswith('.csv') and file.startswith('1')]
for file in files:
    # if np.random.random() < 0.7:
    # print(file)
    shutil.move(folder+file, folderto+file)
# Out:
# ./data/quorum_sims_70_30_split/

# %%
folder_test = folder + 'test/'
files = os.listdir(folder_test)
files = [file for file in files if file.endswith('.csv')]
# fileNames = []
# siteConv = []
# timeConv = []
# siteQuals = []
# sitePoses = []
# numAg = []
submeta = pd.DataFrame([],columns=meta.columns)

for file in files:
    row = meta.loc[meta.file_name==file].values
    try:
        submeta.loc[-1] = row[0]  # adding a row
    except:
        pdb.set_trace()
    # break
    submeta.index = submeta.index + 1  # shifting index
    submeta = submeta.sort_index()  # sorting by index
    # fileNames.append(row.file_name)
    # siteConv.append(row.site_converged)
    # timeConv.append(row.time_converged)
    # siteQuals.append(row.site_qualities)
    # sitePoses.append(row.site_positions)
    # numAg.append(row.num_agents)
    # break
submeta.to_csv(folder_test+'metadata.csv')
# row
# [(fileName, site_conv, time_conv, entry, folder, folder_graph1, folder_graph2)
