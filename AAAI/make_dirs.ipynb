# %%
import os 

folder = 'data/multirunsims/'

os.mkdir(folder + 'test')
os.mkdir(folder + 'train')
os.mkdir(folder + 'graphs')
os.mkdir(folder + 'graphs/test')
os.mkdir(folder + 'graphs/train')
os.mkdir(folder + 'graphs/train_means')
os.mkdir(folder + 'graphs/test_means')
