# %%
import pickle
import numpy as np
import os

# %%
valfolder = './data/quorum_sims_all/graphs/train/'
files_val= os.listdir(valfolder)
files_val = [file for file in files_val if file.endswith('.pickle') and file.startswith('(')]

# %%
new_folder = './data/quorum_sims_all/graphs/train_near_convergence/'
